# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/lelange/Uni/Projektarbeit/rag/testing/models/test_results_scored.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = pd.read_csv("/Users/lelange/Uni/Projektarbeit/rag/testing/models/test_results_scored.csv")
#
# File /opt/anaconda3/envs/rag/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/rag/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/envs/rag/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/envs/rag/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda3/envs/rag/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/lelange/Uni/Projektarbeit/rag/testing/models/test_results_scored.csv'

# %%
# Mapping: Modellname → (Zeitspalte, Score-Spalte)
models = {
    "gemma_7b": ("answer_gemma7b_time", "score_gemma7b"),
    "orca_mini_7b": ("answer_orca-mini7b_time", "score_orca-mini7b"),
    "mistral_7b": ("answer_mistral_latest_time", "score_mistral_latest"),
    "phi4_latest": ("answer_phi4_latest_time", "score_phi4_latest"),
    "qwen25_14b": ("answer_qwen2_5_14b_time", "score_qwen2_5_14b"),
    "orca_mini_13b": ("answer_orca-mini_13b_time", "score_orca-mini_13b"),
    "gemma3_27b": ("answer_gemma3_27b_time", "score_gemma3_27b"),
    "deepseek_r1_32b": ("answer_deepseek_r1_32b_time", "score_deepseek_r1_32b"),
    "qwq_latest": ("answer_qwq_latest_time", "score_qwq_latest")
}

# Ergebnisse berechnen
results = []

for model_name, (time_col, score_col) in models.items():
    if time_col in data.columns and score_col in data.columns:
        time_series = pd.to_numeric(data[time_col], errors='coerce')
        score_series = pd.to_numeric(data[score_col], errors='coerce')
        avg_time = round(time_series.mean(skipna=True), 2)
        avg_score = round(score_series.mean(skipna=True), 4)
        percentage_07 = (score_series <= 0.7).sum() / len(data) * 100
        percentage_08 = (score_series >= 0.8).sum() / len(data) * 100
        percentage_09 = (score_series >= 0.9).sum() / len(data) * 100

        results.append({
            "model": model_name,
            "avg_time_to_answer": avg_time,
            "avg_score": avg_score,
            "worse_than_07": f"{percentage_07:.2f}%",
            "better_than_08": f"{percentage_08:.2f}%",
            "better_than_09": f"{percentage_09:.2f}%"
        })
    else:
        print(f"⚠️  Spalten fehlen für Modell '{model_name}': {time_col}, {score_col}")

# Ergebnis als DataFrame
summary_df = pd.DataFrame(results)

# %%
display(summary_df)
# Out:
#              model  avg_time_to_answer  avg_score worse_than_07  \
# 0         gemma_7b                5.12     0.6012        48.15%
# 1     orca_mini_7b                5.32     0.6247        49.38%
# 2       mistral_7b                5.94     0.6728        46.91%
# 3      phi4_latest               11.48     0.6877        37.04%
# 4       qwen25_14b               10.46     0.6805        39.51%
# 5    orca_mini_13b                7.84     0.6591        45.68%
# 6       gemma3_27b               13.81     0.7214        33.33%
# 7  deepseek_r1_32b               33.38     0.7235        38.27%
# 8       qwq_latest               47.44     0.7165        30.86%
#
#   better_than_08 better_than_09
# 0         48.15%         35.80%
# 1         38.27%         27.16%
# 2         51.85%         43.21%
# 3         55.56%         41.98%
# 4         53.09%         44.44%
# 5         44.44%         33.33%
# 6         56.79%         44.44%
# 7         58.02%         48.15%
# 8         61.73%         49.38%

# %%
df_gemma3_27b_bad_answers = data[data["score_gemma3_27b"]<=0.2]

# %%
df_gemma3_27b_bad_answers.to_csv

# %%
display(df_gemma3_27b_bad_answers[["question"]])
# Out:
#                                              question  \
# 7            Wann haben die THWS Gebäude geschlossen?
# 12  Wo finde ich das studentischen Gesundheitsmana...
# 14  An wen kann ich mich wenden, wenn ich fragen z...
# 17  Wann findet die nächste Public Climate School ...
# 35  Welche Voraussetzungen muss ich erfüllen, um a...
# 39  Ist der online Studiengang Software Engineerin...
# 50  In welchem Raum ist der Hochschulservice Studium?
# 52                      Wo finde ich das Dekanat FIW?
# 76  Wie erreiche ich die Fachschaft der Wirtschaft...
# 79          Mein E-learning Zugang funktioniert nicht
#
#                                        correct_answer
# 7   Die aktuellen vorlesungsfreien Termine, sowie ...
# 12  In Würzburg: Tiepolostraße 6, Raum T.D.39 (Dac...
# 14  Die Ansprechpartner aus dem Nachhaltigkeitstea...
# 17  Vom 24. bis 28. November 2025 findet die nächs...
# 35  Voraussetzung für die Zulassung zum Bachelorst...
# 39  Nein, der Studiengang kostet pro Semester 600 ...
# 50      I.1.45, Sanderheinrichsleitenweg 20, Würzburg
# 52  Im Gebäude der Fakultät am Sanderheinrichsleit...
# 76        Am besten über die Mail: FIW.stv[at]thws.de
# 79  Bei fragen zu Technischen Problemen melde dich...
